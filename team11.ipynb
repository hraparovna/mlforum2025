# %% [markdown]
# # Критерии и условие задачи
#
# 1) Моделирование опроса населения об инфляционных ожиданиях
#
# 2) Выставление кредитного рейтинга компании
#
# 3) Поведение розничных инвесторов на бирже
#
# 4) Своя задача: не похожая на 1-3, в домене БР, обоснованное применение (+10 баллов)

# %%
from google.colab import drive
drive.mount('/content/drive')
